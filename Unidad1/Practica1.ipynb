# %% [markdown]
# <a href="https://colab.research.google.com/github/EdgarLiraV/Probabilidad-y-Estadistica/blob/main/Unidad1/Practica1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Logo IRD.jpg](data:image/jpeg;base64,...)
# ![images.png](data:image/png;base64,...)
# #Probabilidad y Estadistica
# ##Unidad 1
# Practica 1
#
# Grupo:2YY
#
# Alumnos: Edgar Alexis Lira Valadez
#
# Docente: Dr. Jose Gabriel Rodriguez Rivas

# %% [markdown]
# #Ejemplo 1

# %%
from statistics import *

# %%
grupoa = [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]
print(grupoa)
# Out:
# [70, 70, 65, 90, 100, 95, 45, 80, 73, 20, 100, 96]

# %%
promedio = sum(grupoa) / len(grupoa)
print(promedio)
# Out:
# 75.33333333333333

# %%
promedio2 = mean(grupoa)
print(promedio2)
# Out:
# 75.33333333333333

# %%
mediana = median(grupoa)
print(mediana)
# Out:
# 76.5

# %%
moda = mode(grupoa)
print(moda)
# Out:
# 70

# %% [markdown]
# #Ejemplo 2

# %%
tiempos100s = [15.10, 17.20, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.10, 17.20]
print(tiempos100s)
# Out:
# [15.1, 17.2, 14.69, 13.27, 22.15, 18.71, 19.15, 20.65, 15.1, 17.2]

# %%
print("El tiempo promedio de los corredores es=>", mean(tiempos100s))
# Out:
# El tiempo promedio de los corredores es=> 17.322

# %%
mediana = median(tiempos100s)
print("La mediana de los tiempos de los corredores es=>", mediana)
# Out:
# La mediana de los tiempos de los corredores es=> 17.2

# %%
moda = mode(tiempos100s)
print("La moda de los tiempos es=>", moda)
# Out:
# La moda de los tiempos es=> 15.1

# %% [markdown]
# #Ejemplo 3

# %%
import random

# %%
fabrica1 = []
for i in range(100):
  numero_aleatorio = round( random.uniform(50, 100), 2)
  fabrica1.append(numero_aleatorio)
print(fabrica1)
# Out:
# [61.54, 51.27, 74.51, 95.58, 72.65, 64.48, 88.86, 67.34, 94.02, 55.28, 76.77, 64.73, 58.68, 90.36, 99.73, 60.38, 55.37, 68.42, 83.12, 52.89, 67.52, 74.75, 94.51, 84.99, 70.43, 73.78, 76.83, 96.41, 61.5, 70.88, 91.26, 62.98, 53.5, 55.62, 62.85, 52.63, 84.0, 74.95, 83.8, 87.85, 64.27, 85.87, 80.36, 70.19, 79.03, 53.35, 90.93, 88.28, 51.18, 70.33, 72.93, 53.57, 59.39, 91.28, 55.85, 58.32, 71.8, 73.47, 88.66, 81.78, 86.75, 63.86, 63.13, 92.14, 51.35, 85.75, 60.22, 53.35, 67.95, 94.76, 62.71, 99.49, 52.51, 78.0, 97.46, 83.07, 87.48, 74.05, 64.09, 53.47, 78.58, 76.88, 58.54, 99.88, 94.93, 54.25, 84.19, 76.38, 98.38, 95.45, 65.36, 77.61, 88.89, 98.74, 51.17, 84.17, 96.54, 93.0, 73.18, 71.98]

# %%
fabrica2 = []
for i in range(100):
  numero_aleatorio2 = round( random.uniform(50, 100), 2)
  fabrica2.append(numero_aleatorio2)
print(fabrica2)
# Out:
# [79.08, 97.18, 78.53, 54.2, 80.18, 58.7, 72.77, 79.71, 58.27, 69.4, 84.37, 62.35, 89.12, 55.01, 78.03, 81.2, 81.08, 60.64, 57.92, 60.19, 97.95, 51.61, 73.75, 82.57, 68.49, 81.09, 56.83, 50.1, 96.92, 72.48, 79.5, 62.6, 80.15, 58.15, 59.26, 97.62, 90.58, 59.11, 90.53, 82.79, 93.19, 54.18, 85.32, 84.18, 88.92, 92.33, 71.02, 93.84, 65.01, 94.28, 85.28, 55.93, 85.28, 72.58, 87.19, 77.08, 71.73, 93.79, 99.33, 67.17, 64.08, 56.61, 80.38, 72.53, 83.75, 66.45, 75.32, 53.19, 67.19, 66.49, 53.22, 80.28, 71.1, 59.46, 63.33, 76.17, 71.58, 69.47, 54.57, 56.54, 57.7, 75.46, 66.26, 59.68, 76.89, 62.78, 54.33, 90.99, 92.29, 78.63, 54.09, 94.5, 90.35, 70.2, 83.36, 94.03, 97.51, 50.0, 68.44, 81.38]

# %%
import matplotlib.pyplot as plt

# %%
plt.hist(fabrica1)
plt.title("Produccion diaria de la Fabrica 1")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la Fabrica 1')

# %%
plt.hist(fabrica2)
plt.title("Produccion diaria de la Fabrica 2")
# Out:
# Text(0.5, 1.0, 'Produccion diaria de la Fabrica 2')

# %%
media1 = mean(fabrica1)
mediana1 = median(fabrica1)
moda1 = mode(fabrica1)
print("Valores de la fabrica 1")
print("La media de la fabrica 1 es=", media1)
print("La mediana de la fabrica 1 es=", mediana1)
print("La moda de la fabrica 1 es=", moda1)
# Out:
# Valores de la fabrica 1
# La media de la fabrica 1 es= 74.4755
# La mediana de la fabrica 1 es= 73.91499999999999
# La moda de la fabrica 1 es= 53.35

# %%
media2 = mean(fabrica2)
mediana2 = median(fabrica2)
moda2 = mode(fabrica2)
print("Valores de la fabrica 1")
print("La media de la fabrica 1 es=", media2)
print("La mediana de la fabrica 1 es=", mediana2)
print("La moda de la fabrica 1 es=", moda2)
# Out:
# Valores de la fabrica 1
# La media de la fabrica 1 es= 73.8822
# La mediana de la fabrica 1 es= 73.25999999999999
# La moda de la fabrica 1 es= 85.28

# %%
fig, (ax1, ax2) = plt.subplots(nrows =1, ncols=2, figsize=(10, 5))
ax1.hist(fabrica1)
ax2.hist(fabrica2)
plt.show()

# %%
plt.hist(fabrica1, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media1, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana1, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda1, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('valor')
plt.ylabel('Frecuencia')
plt.title('Produccion diaria de la Fabrica 1')
plt.legend()
plt.show()

# %%
plt.hist(fabrica2, bins=10, alpha=0.2, color='b', edgecolor = "black")
plt.axvline(media2, color='b', linestyle='dashed', linewidth=2, label='Media')
plt.axvline(mediana2, color='r', linestyle='dashed', linewidth=2, label='Mediana')
plt.axvline(moda2, color='y', linestyle='dashed', linewidth=2, label='Moda')
plt.xlabel('valor')
plt.ylabel('Frecuencia')
plt.title('Produccion diaria de la Fabrica 2')
plt.legend()
plt.show()
