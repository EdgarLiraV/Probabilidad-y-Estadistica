# %% [markdown]
# <a href="https://colab.research.google.com/github/EdgarLiraV/Probabilidad-y-Estadistica/blob/main/Practica_4_y_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![images.png](data:image/png;base64,...)
# ![Logo IRD.jpg](data:image/jpeg;base64,...)
# #Probabilidad y Estadistica
# #Unidad 1
# ##Practica 4. Tabla de frecuencias
# Facilitador: Dr.Jose Gabriel Rodriguez Rivas
#
# Grupo: 2YY
#
# Alumno Edgar Alexis Lira Valadez

# %%
import random

# %%
edades = []
for i in range(100):
  numero_aleatorio = random.randint(18, 70)
  edades.append(numero_aleatorio)
print(edades)
# Out:
# [31, 40, 59, 37, 65, 20, 49, 66, 60, 28, 28, 48, 53, 59, 53, 24, 66, 48, 41, 59, 63, 47, 25, 27, 37, 64, 68, 21, 40, 52, 46, 27, 23, 64, 20, 62, 36, 59, 41, 32, 33, 61, 25, 22, 19, 19, 28, 42, 62, 50, 40, 55, 32, 21, 47, 22, 30, 65, 30, 48, 39, 59, 65, 48, 26, 66, 27, 62, 51, 70, 51, 66, 35, 35, 69, 38, 58, 39, 49, 39, 41, 51, 35, 33, 40, 70, 28, 44, 55, 61, 37, 20, 57, 24, 49, 21, 45, 35, 65, 40]

# %%
import pandas as pd

# %%
df = pd.DataFrame(edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    31
# 1    40
# 2    59
# 3    37
# 4    65

# %%
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns = ['Edad', 'Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')
print(tabla_frecuencias)
# Out:
#     Edad  Frecuencia
# 19    19           2
# 13    20           3
# 8     21           3
# 20    22           2
# 36    23           1
# 27    24           2
# 25    25           2
# 32    26           1
# 9     27           3
# 5     28           4
# 17    30           2
# 35    31           1
# 23    32           2
# 22    33           2
# 2     35           4
# 39    36           1
# 14    37           3
# 30    38           1
# 11    39           3
# 0     40           5
# 10    41           3
# 38    42           1
# 33    44           1
# 45    45           1
# 40    46           1
# 26    47           2
# 6     48           4
# 12    49           3
# 37    50           1
# 15    51           3
# 41    52           1
# 28    53           2
# 16    55           2
# 34    57           1
# 31    58           1
# 1     59           5
# 44    60           1
# 21    61           2
# 7     62           3
# 43    63           1
# 24    64           2
# 3     65           4
# 4     66           4
# 42    68           1
# 29    69           1
# 18    70           2

# %%
tabla_frecuencias['Frec_Relativa'] = tabla_frecuencias['Frecuencia'] / 100
print(tabla_frecuencias)
# Out:
#     Edad  Frecuencia  Frec_Relativa
# 19    19           2           0.02
# 13    20           3           0.03
# 8     21           3           0.03
# 20    22           2           0.02
# 36    23           1           0.01
# 27    24           2           0.02
# 25    25           2           0.02
# 32    26           1           0.01
# 9     27           3           0.03
# 5     28           4           0.04
# 17    30           2           0.02
# 35    31           1           0.01
# 23    32           2           0.02
# 22    33           2           0.02
# 2     35           4           0.04
# 39    36           1           0.01
# 14    37           3           0.03
# 30    38           1           0.01
# 11    39           3           0.03
# 0     40           5           0.05
# 10    41           3           0.03
# 38    42           1           0.01
# 33    44           1           0.01
# 45    45           1           0.01
# 40    46           1           0.01
# 26    47           2           0.02
# 6     48           4           0.04
# 12    49           3           0.03
# 37    50           1           0.01
# 15    51           3           0.03
# 41    52           1           0.01
# 28    53           2           0.02
# 16    55           2           0.02
# 34    57           1           0.01
# 31    58           1           0.01
# 1     59           5           0.05
# 44    60           1           0.01
# 21    61           2           0.02
# 7     62           3           0.03
# 43    63           1           0.01
# 24    64           2           0.02
# 3     65           4           0.04
# 4     66           4           0.04
# 42    68           1           0.01
# 29    69           1           0.01
# 18    70           2           0.02

# %%
tabla_frecuencias['Frec. Porcentual'] = tabla_frecuencias['Frec_Relativa'] /100 * 100
print(tabla_frecuencias)
# Out:
#     Edad  Frecuencia  Frec_Relativa  Frec. Porcentual
# 19    19           2           0.02              0.02
# 13    20           3           0.03              0.03
# 8     21           3           0.03              0.03
# 20    22           2           0.02              0.02
# 36    23           1           0.01              0.01
# 27    24           2           0.02              0.02
# 25    25           2           0.02              0.02
# 32    26           1           0.01              0.01
# 9     27           3           0.03              0.03
# 5     28           4           0.04              0.04
# 17    30           2           0.02              0.02
# 35    31           1           0.01              0.01
# 23    32           2           0.02              0.02
# 22    33           2           0.02              0.02
# 2     35           4           0.04              0.04
# 39    36           1           0.01              0.01
# 14    37           3           0.03              0.03
# 30    38           1           0.01              0.01
# 11    39           3           0.03              0.03
# 0     40           5           0.05              0.05
# 10    41           3           0.03              0.03
# 38    42           1           0.01              0.01
# 33    44           1           0.01              0.01
# 45    45           1           0.01              0.01
# 40    46           1           0.01              0.01
# 26    47           2           0.02              0.02
# 6     48           4           0.04              0.04
# 12    49           3           0.03              0.03
# 37    50           1           0.01              0.01
# 15    51           3           0.03              0.03
# 41    52           1           0.01              0.01
# 28    53           2           0.02              0.02
# 16    55           2           0.02              0.02
# 34    57           1           0.01              0.01
# 31    58           1           0.01              0.01
# 1     59           5           0.05              0.05
# 44    60           1           0.01              0.01
# 21    61           2           0.02              0.02
# 7     62           3           0.03              0.03
# 43    63           1           0.01              0.01
# 24    64           2           0.02              0.02
# 3     65           4           0.04              0.04
# 4     66           4           0.04              0.04
# 42    68           1           0.01              0.01
# 29    69           1           0.01              0.01
# 18    70           2           0.02              0.02

# %%
tabla_frecuencias['Frec_Acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
print(tabla_frecuencias)
# Out:
#     Edad  Frecuencia  Frec_Relativa  Frec. Porcentual  Frec_Acumulada
# 19    19           2           0.02              0.02               2
# 13    20           3           0.03              0.03               5
# 8     21           3           0.03              0.03               8
# 20    22           2           0.02              0.02              10
# 36    23           1           0.01              0.01              11
# 27    24           2           0.02              0.02              13
# 25    25           2           0.02              0.02              15
# 32    26           1           0.01              0.01              16
# 9     27           3           0.03              0.03              19
# 5     28           4           0.04              0.04              23
# 17    30           2           0.02              0.02              25
# 35    31           1           0.01              0.01              26
# 23    32           2           0.02              0.02              28
# 22    33           2           0.02              0.02              30
# 2     35           4           0.04              0.04              34
# 39    36           1           0.01              0.01              35
# 14    37           3           0.03              0.03              38
# 30    38           1           0.01              0.01              39
# 11    39           3           0.03              0.03              42
# 0     40           5           0.05              0.05              47
# 10    41           3           0.03              0.03              50
# 38    42           1           0.01              0.01              51
# 33    44           1           0.01              0.01              52
# 45    45           1           0.01              0.01              53
# 40    46           1           0.01              0.01              54
# 26    47           2           0.02              0.02              56
# 6     48           4           0.04              0.04              60
# 12    49           3           0.03              0.03              63
# 37    50           1           0.01              0.01              64
# 15    51           3           0.03              0.03              67
# 41    52           1           0.01              0.01              68
# 28    53           2           0.02              0.02              70
# 16    55           2           0.02              0.02              72
# 34    57           1           0.01              0.01              73
# 31    58           1           0.01              0.01              74
# 1     59           5           0.05              0.05              79
# 44    60           1           0.01              0.01              80
# 21    61           2           0.02              0.02              82
# 7     62           3           0.03              0.03              85
# 43    63           1           0.01              0.01              86
# 24    64           2           0.02              0.02              88
# 3     65           4           0.04              0.04              92
# 4     66           4           0.04              0.04              96
# 42    68           1           0.01              0.01              97
# 29    69           1           0.01              0.01              98
# 18    70           2           0.02              0.02             100

# %%
import random

# %%
print(edades)
# Out:
# [31, 40, 59, 37, 65, 20, 49, 66, 60, 28, 28, 48, 53, 59, 53, 24, 66, 48, 41, 59, 63, 47, 25, 27, 37, 64, 68, 21, 40, 52, 46, 27, 23, 64, 20, 62, 36, 59, 41, 32, 33, 61, 25, 22, 19, 19, 28, 42, 62, 50, 40, 55, 32, 21, 47, 22, 30, 65, 30, 48, 39, 59, 65, 48, 26, 66, 27, 62, 51, 70, 51, 66, 35, 35, 69, 38, 58, 39, 49, 39, 41, 51, 35, 33, 40, 70, 28, 44, 55, 61, 37, 20, 57, 24, 49, 21, 45, 35, 65, 40]

# %%
import math

# %%
n = len(edades)
k = int(1 + math.log2(100))
print("Valor de n = ", n, " \nNumero de intervalos =", k)
# Out:
# Valor de n =  100
# Numero de intervalos = 7

# %%
tabla_frecuencias = pd.cut(df['Edad'], bins=k, include_lowest=True).value_counts().reset_index()
tabla_frecuencias.columns = ['Clase', 'Frec']
tabla_frecuencias
# Out:
#               Clase  Frec
# 0  (33.571, 40.857]    17
# 1  (18.948, 26.286]    16
# 2    (62.714, 70.0]    15
# 3  (26.286, 33.571]    14
# 4  (40.857, 48.143]    13
# 5  (55.429, 62.714]    13
# 6  (48.143, 55.429]    12

# %%
tabla_frecuencias = tabla_frecuencias.sort_values(by='Clase')
tabla_frecuencias
# Out:
#               Clase  Frec
# 1  (18.948, 26.286]    16
# 3  (26.286, 33.571]    14
# 0  (33.571, 40.857]    17
# 4  (40.857, 48.143]    13
# 6  (48.143, 55.429]    12
# 5  (55.429, 62.714]    13
# 2    (62.714, 70.0]    15

# %%
tabla_frecuencias['Frec_Relativa'] = tabla_frecuencias['Frec'] / n
tabla_frecuencias['Frec. Porc'] = tabla_frecuencias['Frec_Relativa'] * 100
tabla_frecuencias['Frec Ac'] = tabla_frecuencias['Frec'].cumsum()
tabla_frecuencias['Frec Rel Ac'] = tabla_frecuencias['Frec_Relativa'].cumsum()
tabla_frecuencias['Frec Porc Ac'] = tabla_frecuencias['Frec. Porc'].cumsum()
print(tabla_frecuencias)
# Out:
#               Clase  Frec  Frec_Relativa  Frec. Porc  Frec Ac  Frec Rel Ac  \
# 1  (18.948, 26.286]    16           0.16        16.0       16         0.16
# 3  (26.286, 33.571]    14           0.14        14.0       30         0.30
# 0  (33.571, 40.857]    17           0.17        17.0       47         0.47
# 4  (40.857, 48.143]    13           0.13        13.0       60         0.60
# 6  (48.143, 55.429]    12           0.12        12.0       72         0.72
# 5  (55.429, 62.714]    13           0.13        13.0       85         0.85
# 2    (62.714, 70.0]    15           0.15        15.0      100         1.00
#
#    Frec Porc Ac
# 1          16.0
# 3          30.0
# 0          47.0
# 4          60.0
# 6          72.0
# 5          85.0
# 2         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha =0.5)
plt.title("Histograma de edades basado en la funcion matplotliv con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion matplotliv con valores estandar')

# %%
plt.hist(df['Edad'], bins=k, alpha = 0.5)
plt.title("Histograma de edades basado en la regla de Sturges")
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')

# %% [markdown]
# #PRACTICA 5
# #Diagrama de Cajas y bigotes

# %%
import random
edades2 = []
for i in range(100):
  numero_aleatorio = random.randint(20, 87)
  edades2.append(numero_aleatorio)
print(edades2)
# Out:
# [45, 47, 36, 28, 52, 76, 54, 45, 48, 37, 81, 74, 36, 72, 44, 78, 77, 25, 59, 44, 57, 84, 35, 48, 32, 61, 25, 68, 73, 82, 53, 33, 51, 67, 24, 35, 66, 42, 54, 39, 63, 24, 86, 48, 24, 40, 52, 68, 34, 34, 39, 47, 56, 70, 57, 30, 50, 45, 31, 77, 54, 79, 53, 21, 41, 71, 65, 45, 41, 21, 56, 57, 86, 85, 66, 32, 61, 75, 65, 51, 53, 25, 80, 41, 79, 64, 77, 44, 70, 55, 64, 72, 35, 78, 78, 87, 31, 79, 53, 84]

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades, vert = True, patch_artist=True)
ax1.set_title('Edades Enceusta 1')
bplot2 = ax2.boxplot(edades2, vert = True, patch_artist=True)
ax2.set_title('Edades Enceusta 2')
plt.show()

# %%
edades2.append(130)

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(9, 4))
bplot1 = ax1.boxplot(edades, vert = True, patch_artist=True)
ax1.set_title('Edades Enceusta 1')
bplot2 = ax2.boxplot(edades2, vert = True, patch_artist=True)
ax2.set_title('Edades Enceusta 2')
plt.show()
